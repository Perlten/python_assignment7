# %% [markdown]
# # Find the top 10 players with the most kills on origin/pc

# %%
    import module

    print("Top 10 Kills")
    kills = module.get_top_10(module.get_soup_from_html_file("kills.html"))
    module.print_top_10(kills)
# Out:
# Top 10 Kills
# Place: 1
# Name: Daltoosh
# Kills: 20,171
#
# Place: 2
# Name: TSM_DIEGOSAURS
# Kills: 19,838
#
# Place: 3
# Name: Termk47
# Kills: 19,549
#
# Place: 4
# Name: Finicki-
# Kills: 18,907
#
# Place: 5
# Name: Joker47jk
# Kills: 18,022
#
# Place: 6
# Name: DespeTTV
# Kills: 17,722
#
# Place: 7
# Name: RhinoTTV
# Kills: 17,499
#
# Place: 8
# Name: Cujothagod
# Kills: 17,107
#
# Place: 9
# Name: F44LA
# Kills: 16,795
#
# Place: 10
# Name: 100T_lifted
# Kills: 16,664

# %% [markdown]
# # For each weapon type find the player with the most kills with that weapon

# %%
    # Get html from local html file
    print("Top 10 shotgun Kills")
    shotgun_kills = module.get_top_10(module.get_soup_from_html_file("shotgunKills.html"))
    module.print_top_10(shotgun_kills)
    
    print("----------------------------------------------\n")
    
    # Downloads html file from url
    print("Top 10 pistol kills")
    pistol_kills = module.get_top_10(module.get_soup_from_url(module.pistol_url))
    module.print_top_10(pistol_kills)
    
    print("----------------------------------------------\n")
    
    # Get html from local html file
    print("Top 10 AR kills")
    ar_kills = module.get_top_10(module.get_soup_from_html_file("arKills.html"))
    module.print_top_10(ar_kills)
# Out:
# Top 10 shotgun Kills
# Place: 1
# Name: Twitch-Ceryal_
# Kills: 4,347
#
# Place: 2
# Name: WhizkmTTV
# Kills: 3,437
#
# Place: 3
# Name: TheGodofshotguns
# Kills: 3,088
#
# Place: 4
# Name: Zxlesserevilxz
# Kills: 3,080
#
# Place: 5
# Name: Finicki-
# Kills: 2,946
#
# Place: 6
# Name: poppamiez-
# Kills: 2,905
#
# Place: 7
# Name: EdnsIV
# Kills: 2,863
#
# Place: 8
# Name: SmurfingBro-_-
# Kills: 2,811
#
# Place: 9
# Name: Chillguin_Twitch
# Kills: 2,800
#
# Place: 10
# Name: One pumps ttv
# Kills: 2,785
#
# ----------------------------------------------
#
# Top 10 pistol kills
# Place: 1
# Name: PENTA-viktoras
# Kills: 6,605
#
# Place: 2
# Name: Finicki-
# Kills: 5,771
#
# Place: 3
# Name: Alpoooooooke_
# Kills: 5,404
#
# Place: 4
# Name: Ino_meercy
# Kills: 5,184
#
# Place: 5
# Name: Douyu_Kael
# Kills: 5,111
#
# Place: 6
# Name: Crazyslot_-
# Kills: 5,093
#
# Place: 7
# Name: X0NIQ
# Kills: 4,508
#
# Place: 8
# Name: plzgodno
# Kills: 4,444
#
# Place: 9
# Name: Blank_Nitrox
# ...
